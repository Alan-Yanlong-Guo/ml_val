# %%
import wrds
import pandas as pd
import numpy as np
from backtest.backtest import backtest
from backtest.analysis import compute_stats, plot_return
# Out:
# Loading library list...
# Done

# %%
return_df = backtest(2015, 2015)
stats = compute_stats(return_df, 'long', 'value')
fig = plot_return(return_df)

# %%
from math import sin
from random import random

from bokeh.io import output_file, output_notebook, show
from bokeh.models import ColumnDataSource, HoverTool, LinearColorMapper
from bokeh.palettes import plasma
from bokeh.plotting import figure
from bokeh.transform import transform
import matplotlib.pyplot as plt 

hover = HoverTool(point_policy='follow_mouse', show_arrow=True, mode='vline', 
                  tooltips=[("index", "$index"), ("(x,y)", "(@x, @y)"), ('desc', '@desc')])
p = figure(plot_width=700, plot_height=400, tools=[hover], title="Belgian test")

list_x = list(range(100))
list_y = [random() + sin(i / 20) for i in range(100)]
desc = [str(i) for i in list_y]
source = ColumnDataSource(data=dict(x=list_x, y=list_y, desc=desc))
mapper = LinearColorMapper(palette=plasma(256), low=min(list_y), high=max(list_y))
p.circle('x', 'y', size=10, source=source,
         fill_color=transform('y', mapper))
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3352">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="13afcbc8-2fe9-4f4f-930c-d531378a8274" data-root-id="3324"></div>
